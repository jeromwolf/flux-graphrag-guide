# %% [markdown]
# # Part 2: 수작업 Knowledge Graph 구축 -- 제조 도메인(브레이크패드)
#
# **소요 시간**: ~2시간
# **난이도**: 초급
#
# ---
#
# ## 학습 목표
#
# | # | 목표 | 설명 |
# |---|------|------|
# | 1 | **온톨로지 설계** | 제조 도메인에 맞는 7개 엔티티 타입, 9개 관계 타입을 정의합니다 |
# | 2 | **수동 엔티티/관계 추출** | 비정형 텍스트(제조 문서)에서 사람이 직접 엔티티와 관계를 추출합니다 |
# | 3 | **Meta-Dictionary 생성** | 관계 타입별 한국어 키워드 사전을 만들어 추출 일관성을 높입니다 |
# | 4 | **Neo4j 적재 + 검증** | MERGE 패턴으로 15~20개 노드 그래프를 구축하고 Multi-hop 쿼리로 검증합니다 |
#
# ---
#
# ## Part 1 복습
#
# Part 1(EP1)에서 우리는 **7개 노드**로 된 제조 그래프를 만들고,
# 3-hop 근본원인 추적 쿼리의 위력을 체험했습니다.
#
# 이번 Part 2에서는 한 단계 더 나아갑니다:
# **비정형 텍스트(제조 문서 5개)에서 지식 그래프를 수작업으로 만드는 전체 프로세스**를 배웁니다.
# 노드 수를 **15~20개로 확장**하고, 온톨로지를 체계적으로 설계합니다.
#
# > **왜 수작업부터?**
# > Part 3에서 LLM으로 자동화하기 전에, 사람이 직접 해봐야 LLM 결과의 품질을 판단할 수 있습니다.
# > 수동 추출 결과가 **Gold Standard**가 되어 자동 추출의 기준이 됩니다.
#
# ---
#
# ## 목차
#
# 1. 환경 설정
# 2. 제조 문서 로드
# 3. 온톨로지 설계
# 4. Meta-Dictionary 생성
# 5. 수동 추출 시연 -- 문서 1, 2
# 6. 수동 추출 -- 문서 3, 4, 5
# 7. 추출 통합 + 통계
# 8. Neo4j 적재
# 9. 검증 쿼리
# 10. 정리

# %% [markdown]
# ---
# ## 1. 환경 설정
#
# ### 1.1 패키지 설치 확인
#
# Neo4j Python 드라이버와 `python-dotenv`가 필요합니다.
# 아래 셀을 실행하여 설치 여부를 확인하세요.

# %%
import subprocess, sys

def check_and_install(package_name, import_name=None):
    import_name = import_name or package_name
    try:
        __import__(import_name)
        print(f"[OK] {package_name} 설치 확인 완료")
    except ImportError:
        print(f"[설치 중] {package_name}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package_name, "-q"])
        print(f"[OK] {package_name} 설치 완료")

check_and_install("neo4j")
check_and_install("python-dotenv", "dotenv")

# %% [markdown]
# ### 1.2 Neo4j 연결
#
# 프로젝트 루트의 `.env` 파일에서 접속 정보를 로드합니다.
#
# ```
# NEO4J_URI=bolt://localhost:7687
# NEO4J_USER=neo4j
# NEO4J_PASSWORD=your_password_here
# ```

# %%
import os, json
from dotenv import load_dotenv
from neo4j import GraphDatabase

# 환경 변수 로드
load_dotenv()
load_dotenv(dotenv_path="../.env")

NEO4J_URI = os.getenv("NEO4J_URI", "bolt://localhost:7687")
NEO4J_USER = os.getenv("NEO4J_USER", "neo4j")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "")

# Neo4j 연결
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

try:
    driver.verify_connectivity()
    print("[OK] Neo4j 연결 성공!")
except Exception as e:
    print(f"[ERROR] 연결 실패: {e}")
    print("Neo4j가 실행 중인지, .env 설정이 올바른지 확인하세요.")

# 편의 함수
def run_query(query, parameters=None, print_result=True):
    """Cypher 쿼리를 실행하고 결과를 반환합니다."""
    with driver.session() as session:
        result = session.run(query, parameters or {})
        records = [record.data() for record in result]
        if print_result:
            if records:
                for i, rec in enumerate(records, 1):
                    print(f"  [{i}] {rec}")
            else:
                print("  (결과 없음)")
        return records

print("[OK] run_query 함수 준비 완료")

# %% [markdown]
# ---
# ## 2. 제조 문서 로드
#
# `data/manufacturing_docs.json`에 브레이크패드 제조 관련 문서 5개가 준비되어 있습니다.
#
# | # | 문서 | 주요 내용 |
# |---|------|----------|
# | 1 | 생산라인 설비 구성 | MX-100, PR-200, HT-300, GR-400, QC-500 설비 |
# | 2 | 품질 불량 분석 보고서 | 균열 0.8%, 두께편차 0.6%, 마찰계수미달 0.5%, 표면결함 0.4% |
# | 3 | 설비 예방정비 스케줄 | 월/분기/주 단위 정비 주기 |
# | 4 | 원자재 공급망 현황 | 페놀수지(코오롱), 아라미드섬유(효성), 마찰재(TMD) 등 |
# | 5 | 스마트팩토리 AI 도입 | Azure ML, 포스코DX 시스템 구축 |

# %%
with open("data/manufacturing_docs.json", "r", encoding="utf-8") as f:
    docs = json.load(f)

print(f"[OK] {len(docs)}개 문서 로드 완료\n")
print("문서 목록:")
for doc in docs:
    print(f"  [{doc['id']}] {doc['title']}")
    print(f"      {doc['content'][:60]}...\n")

# %% [markdown]
# ---
# ## 3. 온톨로지 설계
#
# Knowledge Graph를 만들려면 먼저 **온톨로지(Ontology)**를 설계해야 합니다.
# 온톨로지란 '우리 도메인에서 어떤 종류의 엔티티와 관계가 존재하는가'를 정의한 스키마입니다.
#
# ### 설계 원칙
#
# 1. **친숙한 도메인을 선택하라** -- 관계의 정확성을 직관적으로 판단할 수 있어야 합니다
# 2. **엔티티 타입은 5~7개로 시작하라** -- 너무 많으면 복잡해지고, 너무 적으면 표현력이 부족합니다
# 3. **관계 타입은 10개 이하로** -- 처음부터 모든 관계를 정의하지 마세요
# 4. **방향이 중요하다** -- `A-[CAUSED_BY]->B`와 `B-[CAUSED_BY]->A`는 완전히 다른 의미입니다
#
# ### 7개 엔티티 타입 (제조 도메인)
#
# | Entity Type | 한글 | 설명 | 예시 |
# |-------------|------|------|------|
# | **Process** | 공정 | 제조 공정 단계 | 혼합, 프레스 성형, 열처리, 연마, 검사 |
# | **Equipment** | 설비 | 공정에 사용되는 장비 | MX-100, PR-200, HT-300, GR-400, QC-500 |
# | **Defect** | 결함 | 품질 불량 유형 | 균열, 두께편차, 마찰계수 미달, 표면 결함 |
# | **Material** | 원자재 | 투입 원자재/소재 | 페놀수지, 아라미드 섬유, 마찰재 분말, 백플레이트, 접착제 |
# | **Product** | 제품 | 완성품 | 브레이크 패드 BP-100 |
# | **Spec** | 규격 | 품질 규격/표준 | KS M 6613, ISO 6310 |
# | **Maintenance** | 정비 | 정비 이력/스케줄 | 블레이드 교체(월1회), 온도센서 교정(월2회) |
#
# ### 9개 관계 타입
#
# | 관계 | 출발 -> 도착 | 설명 | 예시 |
# |------|-------------|------|------|
# | **NEXT_PROCESS** | Process -> Process | 다음 공정 | 혼합 -> 프레스 성형 |
# | **USES_EQUIPMENT** | Process -> Equipment | 설비 사용 | 혼합 -> MX-100 |
# | **USES_MATERIAL** | Process -> Material | 자재 투입 | 혼합 -> 페놀수지 |
# | **CAUSED_BY** | Defect -> Process/Equipment | 결함 원인 | 균열 -> HT-300 |
# | **DETECTED_IN** | Defect -> Process | 결함 발견 공정 | 균열 -> 검사 |
# | **CONFORMS_TO** | Product/Material -> Spec | 규격 준수 | BP-100 -> KS M 6613 |
# | **MAINTAINED_ON** | Equipment -> Maintenance | 정비 이력 | HT-300 -> 온도센서 교정 |
# | **PRODUCES** | Process -> Product | 제품 생산 | 검사 -> BP-100 |
# | **INSPECTED_BY** | Product -> Equipment | 검사 설비 | BP-100 -> QC-500 |

# %% [markdown]
# ### 3.1 온톨로지를 Python 딕셔너리로 정의

# %%
ontology = {
    "entity_types": {
        "Process": {
            "description": "제조 공정",
            "properties": ["name", "process_id", "order"],
            "examples": ["혼합", "프레스 성형", "열처리", "연마", "검사"]
        },
        "Equipment": {
            "description": "설비",
            "properties": ["name", "equipment_id", "manufacturer"],
            "examples": ["MX-100 원료혼합기", "PR-200 프레스기", "HT-300 열처리로", "GR-400 연마기", "QC-500 검사장비"]
        },
        "Defect": {
            "description": "불량/결함",
            "properties": ["name", "defect_id", "rate", "severity"],
            "examples": ["균열", "두께편차", "마찰계수 미달", "표면 결함"]
        },
        "Material": {
            "description": "원자재",
            "properties": ["name", "material_id", "supplier"],
            "examples": ["페놀수지", "아라미드 섬유", "마찰재 분말", "백플레이트", "접착제"]
        },
        "Product": {
            "description": "완성 제품",
            "properties": ["name", "product_id"],
            "examples": ["브레이크 패드 BP-100"]
        },
        "Spec": {
            "description": "품질 규격/표준",
            "properties": ["name", "spec_id"],
            "examples": ["KS M 6613", "ISO 6310"]
        },
        "Maintenance": {
            "description": "정비 이력/스케줄",
            "properties": ["name", "cycle", "person"],
            "examples": ["MX-100 블레이드 교체 (월1회)", "HT-300 온도센서 교정 (월2회)"]
        }
    },
    "relation_types": {
        "NEXT_PROCESS": {
            "source": "Process",
            "target": "Process",
            "description": "다음 공정"
        },
        "USES_EQUIPMENT": {
            "source": "Process",
            "target": "Equipment",
            "description": "설비 사용"
        },
        "USES_MATERIAL": {
            "source": "Process",
            "target": "Material",
            "description": "자재 투입"
        },
        "CAUSED_BY": {
            "source": "Defect",
            "target": "Process/Equipment",
            "description": "결함 원인"
        },
        "DETECTED_IN": {
            "source": "Defect",
            "target": "Process",
            "description": "결함 발견 공정"
        },
        "CONFORMS_TO": {
            "source": "Product/Material",
            "target": "Spec",
            "description": "규격 준수"
        },
        "MAINTAINED_ON": {
            "source": "Equipment",
            "target": "Maintenance",
            "description": "정비 이력"
        },
        "PRODUCES": {
            "source": "Process",
            "target": "Product",
            "description": "제품 생산"
        },
        "INSPECTED_BY": {
            "source": "Product",
            "target": "Equipment",
            "description": "검사 담당 설비"
        }
    }
}

print("=== 엔티티 타입 (7개) ===")
for etype, info in ontology["entity_types"].items():
    print(f"\n  [{etype}] {info['description']}")
    print(f"    속성: {', '.join(info['properties'])}")
    print(f"    예시: {', '.join(info['examples'][:3])}")

print(f"\n\n=== 관계 타입 (9개) ===")
for rtype, info in ontology["relation_types"].items():
    print(f"  {info['source']:20s} -[:{rtype}]-> {info['target']:20s} | {info['description']}")

# 온톨로지 파일 저장
with open("data/ontology_manufacturing.json", "w", encoding="utf-8") as f:
    json.dump(ontology, f, ensure_ascii=False, indent=2)
print(f"\n[OK] 온톨로지를 data/ontology_manufacturing.json에 저장했습니다.")

# %% [markdown]
# ---
# ## 4. Meta-Dictionary 생성
#
# **Meta-Dictionary**는 관계 타입별 한국어 키워드를 매핑한 사전입니다.
# 제조 문서에서 특정 키워드가 나오면 어떤 관계 타입에 해당하는지 빠르게 판단할 수 있습니다.
#
# ### 왜 필요한가?
#
# - **수동 추출 시**: 사람이 일관된 기준으로 관계를 분류할 수 있음
# - **LLM 자동 추출 시 (Part 3)**: 프롬프트에 포함하여 LLM의 추출 정확도를 높임
# - **품질 검증 시**: 추출 결과가 키워드 사전과 일치하는지 확인

# %%
meta_dictionary = {
    "NEXT_PROCESS": {
        "keywords": ["다음", "이후", "후속", "순서", "흐름", "단계"],
        "description": "공정 순서"
    },
    "USES_EQUIPMENT": {
        "keywords": ["사용", "가동", "운전", "설비", "장비", "기계"],
        "description": "설비 사용"
    },
    "USES_MATERIAL": {
        "keywords": ["투입", "배합", "원료", "자재", "소재", "공급"],
        "description": "자재 투입"
    },
    "CAUSED_BY": {
        "keywords": ["원인", "기인", "발생", "유발", "때문", "의해"],
        "description": "결함 원인"
    },
    "DETECTED_IN": {
        "keywords": ["발견", "검출", "확인", "나타남", "불량률"],
        "description": "결함 발견"
    },
    "CONFORMS_TO": {
        "keywords": ["규격", "표준", "KS", "ISO", "준수", "적합"],
        "description": "규격 준수"
    },
    "MAINTAINED_ON": {
        "keywords": ["정비", "점검", "교체", "보수", "캘리브레이션", "교정"],
        "description": "정비 이력"
    },
    "PRODUCES": {
        "keywords": ["생산", "제조", "완성", "출하", "산출"],
        "description": "제품 생산"
    },
    "INSPECTED_BY": {
        "keywords": ["검사", "측정", "시험", "QC", "품질"],
        "description": "검사"
    }
}

# 저장
with open("data/meta_dictionary_manufacturing.json", "w", encoding="utf-8") as f:
    json.dump(meta_dictionary, f, ensure_ascii=False, indent=2)

print("=== Meta-Dictionary (9개 관계 타입) ===")
for rtype, info in meta_dictionary.items():
    kw_str = ", ".join(info["keywords"])
    print(f"\n  [{rtype}]")
    print(f"    {info['description']}")
    print(f"    키워드: {kw_str}")

print(f"\n[OK] Meta-Dictionary를 data/meta_dictionary_manufacturing.json에 저장했습니다.")

# %%
# Meta-Dictionary 활용: 키워드로 관계 타입 추론

def find_relation_type(text):
    """텍스트에서 키워드를 찾아 가능한 관계 타입을 추론합니다."""
    matches = []
    for rtype, info in meta_dictionary.items():
        matched_keywords = [kw for kw in info["keywords"] if kw in text]
        if matched_keywords:
            matches.append({
                "relation_type": rtype,
                "matched_keywords": matched_keywords,
                "score": len(matched_keywords)
            })
    return sorted(matches, key=lambda x: x["score"], reverse=True)

# 테스트
test_sentences = [
    "균열 불량의 70%는 HT-300 열처리로의 온도 편차에서 기인했다.",
    "MX-100 원료혼합기는 월 1회 블레이드 교체 정비를 실시한다.",
    "혼합 공정에서 페놀수지, 아라미드 섬유, 마찰재를 배합한다.",
    "QC-500 검사장비로 마찰계수와 경도를 측정한다."
]

print("=== Meta-Dictionary 키워드 매칭 테스트 ===")
for sent in test_sentences:
    print(f"\n문장: \"{sent}\"")
    matches = find_relation_type(sent)
    if matches:
        for m in matches[:2]:
            print(f"  -> {m['relation_type']} (매칭: {m['matched_keywords']})")
    else:
        print("  -> 매칭된 관계 타입 없음")

# %% [markdown]
# ---
# ## 5. 수동 추출 시연 -- 문서 1, 2
#
# 이제 실제 제조 문서에서 엔티티와 관계를 추출합니다.
#
# ### 추출 프로세스
#
# 1. 문서를 읽는다
# 2. 엔티티(명사)를 식별한다 -> 타입을 분류한다
# 3. 관계(동사/서술어)를 식별한다 -> 타입을 분류한다
# 4. 추출 결과를 구조화된 JSON으로 정리한다
#
# ### 문서 1: 생산라인 설비 구성
#
# 이 문서에서 추출할 수 있는 것:
# - **Equipment** 5개: MX-100, PR-200, HT-300, GR-400, QC-500
# - **Process** 5개: 혼합, 프레스 성형, 열처리, 연마, 검사
# - **Material** 3개: 페놀수지, 아라미드 섬유, 마찰재
# - **Product** 1개: 브레이크 패드 BP-100
# - 관계: USES_EQUIPMENT, NEXT_PROCESS, USES_MATERIAL, PRODUCES

# %%
# 문서 1 내용 확인
doc1 = docs[0]
print(f"=== 문서 #{doc1['id']}: {doc1['title']} ===")
print(f"\n{doc1['content']}")
print("\n" + "=" * 60)
print("아래에서 이 문서의 추출 결과를 확인합니다.")

# %%
# === 문서 1: 생산라인 설비 구성 -- 수동 추출 ===

extraction_01 = {
    "doc_id": 1,
    "entities": [
        # Process (5개 공정)
        {"name": "혼합", "type": "Process", "properties": {"process_id": "PRC-001", "order": 1}},
        {"name": "프레스 성형", "type": "Process", "properties": {"process_id": "PRC-002", "order": 2}},
        {"name": "열처리", "type": "Process", "properties": {"process_id": "PRC-003", "order": 3}},
        {"name": "연마", "type": "Process", "properties": {"process_id": "PRC-004", "order": 4}},
        {"name": "검사", "type": "Process", "properties": {"process_id": "PRC-005", "order": 5}},
        # Equipment (5개 설비)
        {"name": "MX-100 원료혼합기", "type": "Equipment", "properties": {"equipment_id": "MX-100", "manufacturer": "삼성정밀"}},
        {"name": "PR-200 프레스기", "type": "Equipment", "properties": {"equipment_id": "PR-200", "manufacturer": "현대위아"}},
        {"name": "HT-300 열처리로", "type": "Equipment", "properties": {"equipment_id": "HT-300"}},
        {"name": "GR-400 연마기", "type": "Equipment", "properties": {"equipment_id": "GR-400"}},
        {"name": "QC-500 검사장비", "type": "Equipment", "properties": {"equipment_id": "QC-500"}},
        # Material (3개 원자재)
        {"name": "페놀수지", "type": "Material", "properties": {"material_id": "MAT-001"}},
        {"name": "아라미드 섬유", "type": "Material", "properties": {"material_id": "MAT-002"}},
        {"name": "마찰재 분말", "type": "Material", "properties": {"material_id": "MAT-003"}},
        # Product (1개)
        {"name": "브레이크 패드 BP-100", "type": "Product", "properties": {"product_id": "BP-100"}},
    ],
    "relations": [
        # 공정 흐름: NEXT_PROCESS
        {"source": "혼합", "target": "프레스 성형", "type": "NEXT_PROCESS", "properties": {}},
        {"source": "프레스 성형", "target": "열처리", "type": "NEXT_PROCESS", "properties": {}},
        {"source": "열처리", "target": "연마", "type": "NEXT_PROCESS", "properties": {}},
        {"source": "연마", "target": "검사", "type": "NEXT_PROCESS", "properties": {}},
        # 설비 사용: USES_EQUIPMENT
        {"source": "혼합", "target": "MX-100 원료혼합기", "type": "USES_EQUIPMENT", "properties": {}},
        {"source": "프레스 성형", "target": "PR-200 프레스기", "type": "USES_EQUIPMENT", "properties": {"pressure": "150톤"}},
        {"source": "열처리", "target": "HT-300 열처리로", "type": "USES_EQUIPMENT", "properties": {"temp": "200도", "duration": "4시간"}},
        {"source": "연마", "target": "GR-400 연마기", "type": "USES_EQUIPMENT", "properties": {"tolerance": "0.1mm"}},
        {"source": "검사", "target": "QC-500 검사장비", "type": "USES_EQUIPMENT", "properties": {}},
        # 자재 투입: USES_MATERIAL (혼합 공정)
        {"source": "혼합", "target": "페놀수지", "type": "USES_MATERIAL", "properties": {}},
        {"source": "혼합", "target": "아라미드 섬유", "type": "USES_MATERIAL", "properties": {}},
        {"source": "혼합", "target": "마찰재 분말", "type": "USES_MATERIAL", "properties": {}},
        # 제품 생산
        {"source": "검사", "target": "브레이크 패드 BP-100", "type": "PRODUCES", "properties": {}},
        # 검사 설비
        {"source": "브레이크 패드 BP-100", "target": "QC-500 검사장비", "type": "INSPECTED_BY", "properties": {}},
    ]
}

print(f"=== 문서 1 추출 결과 ===")
print(f"\n엔티티 {len(extraction_01['entities'])}개:")
for e in extraction_01["entities"]:
    print(f"  [{e['type']:12s}] {e['name']}")

print(f"\n관계 {len(extraction_01['relations'])}개:")
for r in extraction_01["relations"]:
    print(f"  {r['source']} -[:{r['type']}]-> {r['target']}")

# %%
# 문서 2 내용 확인
doc2 = docs[1]
print(f"=== 문서 #{doc2['id']}: {doc2['title']} ===")
print(f"\n{doc2['content']}")
print("\n" + "=" * 60)

# %%
# === 문서 2: 품질 불량 분석 보고서 -- 수동 추출 ===

extraction_02 = {
    "doc_id": 2,
    "entities": [
        # Defect (4개 불량 유형)
        {"name": "균열", "type": "Defect", "properties": {"defect_id": "DEF-001", "rate": "0.8%", "severity": "High"}},
        {"name": "두께편차", "type": "Defect", "properties": {"defect_id": "DEF-002", "rate": "0.6%", "severity": "Medium"}},
        {"name": "마찰계수 미달", "type": "Defect", "properties": {"defect_id": "DEF-003", "rate": "0.5%", "severity": "High"}},
        {"name": "표면 결함", "type": "Defect", "properties": {"defect_id": "DEF-004", "rate": "0.4%", "severity": "Low"}},
    ],
    "relations": [
        # 결함 원인: CAUSED_BY
        {"source": "균열", "target": "HT-300 열처리로", "type": "CAUSED_BY", "properties": {"detail": "온도 편차", "ratio": "70%"}},
        {"source": "두께편차", "target": "GR-400 연마기", "type": "CAUSED_BY", "properties": {"detail": "마모된 연마석"}},
        # 결함 발견 공정: DETECTED_IN (모든 불량은 검사 공정에서 발견)
        {"source": "균열", "target": "검사", "type": "DETECTED_IN", "properties": {}},
        {"source": "두께편차", "target": "검사", "type": "DETECTED_IN", "properties": {}},
        {"source": "마찰계수 미달", "target": "검사", "type": "DETECTED_IN", "properties": {}},
        {"source": "표면 결함", "target": "검사", "type": "DETECTED_IN", "properties": {}},
    ]
}

print(f"=== 문서 2 추출 결과 ===")
print(f"\n엔티티 {len(extraction_02['entities'])}개:")
for e in extraction_02["entities"]:
    print(f"  [{e['type']:12s}] {e['name']} (불량률: {e['properties'].get('rate', '-')})")

print(f"\n관계 {len(extraction_02['relations'])}개:")
for r in extraction_02["relations"]:
    detail = f" ({r['properties']['detail']})" if 'detail' in r['properties'] else ""
    print(f"  {r['source']} -[:{r['type']}]-> {r['target']}{detail}")

# %% [markdown]
# ---
# ## 6. 수동 추출 -- 문서 3, 4, 5
#
# 나머지 3개 문서에서도 엔티티와 관계를 추출합니다.
#
# - **문서 3** (설비 예방정비): Maintenance 엔티티 + MAINTAINED_ON 관계
# - **문서 4** (원자재 공급망): Material 상세 (supplier 속성) + CONFORMS_TO 관계
# - **문서 5** (AI 도입 계획): 기존 관계 보강 + Spec 엔티티

# %%
# 문서 3 내용 확인
doc3 = docs[2]
print(f"=== 문서 #{doc3['id']}: {doc3['title']} ===")
print(f"\n{doc3['content']}")
print("\n" + "=" * 60)

# === 문서 3: 설비 예방정비 스케줄 -- 수동 추출 ===

extraction_03 = {
    "doc_id": 3,
    "entities": [
        # Maintenance (5개 정비 항목)
        {"name": "블레이드 교체", "type": "Maintenance", "properties": {"cycle": "월1회", "person": "박영호"}},
        {"name": "유압실린더 점검", "type": "Maintenance", "properties": {"cycle": "분기1회", "person": "박영호"}},
        {"name": "온도센서 교정", "type": "Maintenance", "properties": {"cycle": "월2회", "person": "박영호"}},
        {"name": "연마석 상태 확인", "type": "Maintenance", "properties": {"cycle": "주1회", "person": "박영호"}},
        {"name": "캘리브레이션", "type": "Maintenance", "properties": {"cycle": "월1회", "person": "박영호"}},
    ],
    "relations": [
        # 설비 -> 정비: MAINTAINED_ON
        {"source": "MX-100 원료혼합기", "target": "블레이드 교체", "type": "MAINTAINED_ON", "properties": {}},
        {"source": "PR-200 프레스기", "target": "유압실린더 점검", "type": "MAINTAINED_ON", "properties": {}},
        {"source": "HT-300 열처리로", "target": "온도센서 교정", "type": "MAINTAINED_ON", "properties": {}},
        {"source": "GR-400 연마기", "target": "연마석 상태 확인", "type": "MAINTAINED_ON", "properties": {}},
        {"source": "QC-500 검사장비", "target": "캘리브레이션", "type": "MAINTAINED_ON", "properties": {}},
    ]
}

print(f"\n=== 문서 3 추출 결과 ===")
print(f"\n엔티티 {len(extraction_03['entities'])}개:")
for e in extraction_03["entities"]:
    print(f"  [{e['type']:12s}] {e['name']} ({e['properties'].get('cycle', '')})")
print(f"\n관계 {len(extraction_03['relations'])}개:")
for r in extraction_03["relations"]:
    print(f"  {r['source']} -[:{r['type']}]-> {r['target']}")

# %%
# 문서 4 내용 확인
doc4 = docs[3]
print(f"=== 문서 #{doc4['id']}: {doc4['title']} ===")
print(f"\n{doc4['content']}")
print("\n" + "=" * 60)

# === 문서 4: 원자재 공급망 현황 -- 수동 추출 ===

extraction_04 = {
    "doc_id": 4,
    "entities": [
        # Material (supplier 속성 보강 -- 기존 엔티티 속성 업데이트)
        {"name": "페놀수지", "type": "Material", "properties": {"material_id": "MAT-001", "supplier": "코오롱인더스트리", "monthly_supply": "5톤"}},
        {"name": "아라미드 섬유", "type": "Material", "properties": {"material_id": "MAT-002", "supplier": "효성첨단소재", "monthly_supply": "2톤"}},
        {"name": "마찰재 분말", "type": "Material", "properties": {"material_id": "MAT-003", "supplier": "TMD 프릭션", "source": "수입"}},
        {"name": "백플레이트", "type": "Material", "properties": {"material_id": "MAT-004", "supplier": "포스코"}},
        {"name": "접착제", "type": "Material", "properties": {"material_id": "MAT-005", "supplier": "헨켈코리아"}},
    ],
    "relations": [
        # 프레스 성형에서 백플레이트 사용
        {"source": "프레스 성형", "target": "백플레이트", "type": "USES_MATERIAL", "properties": {}},
        # 열처리에서 접착제 사용 (경화 접착 공정)
        {"source": "열처리", "target": "접착제", "type": "USES_MATERIAL", "properties": {}},
    ]
}

print(f"\n=== 문서 4 추출 결과 ===")
print(f"\n엔티티 {len(extraction_04['entities'])}개:")
for e in extraction_04["entities"]:
    supplier = e['properties'].get('supplier', '-')
    print(f"  [{e['type']:12s}] {e['name']} (공급: {supplier})")
print(f"\n관계 {len(extraction_04['relations'])}개:")
for r in extraction_04["relations"]:
    print(f"  {r['source']} -[:{r['type']}]-> {r['target']}")

# %%
# 문서 5 내용 확인
doc5 = docs[4]
print(f"=== 문서 #{doc5['id']}: {doc5['title']} ===")
print(f"\n{doc5['content']}")
print("\n" + "=" * 60)

# === 문서 5: 스마트팩토리 AI 도입 계획 -- 수동 추출 ===

extraction_05 = {
    "doc_id": 5,
    "entities": [
        # Spec (품질 규격)
        {"name": "KS M 6613", "type": "Spec", "properties": {"spec_id": "SPEC-001", "description": "자동차 브레이크 라이닝 및 패드"}},
        {"name": "ISO 6310", "type": "Spec", "properties": {"spec_id": "SPEC-002", "description": "도로차량 브레이크 라이닝"}},
    ],
    "relations": [
        # 제품 -> 규격: CONFORMS_TO
        {"source": "브레이크 패드 BP-100", "target": "KS M 6613", "type": "CONFORMS_TO", "properties": {}},
        {"source": "브레이크 패드 BP-100", "target": "ISO 6310", "type": "CONFORMS_TO", "properties": {}},
    ]
}

print(f"\n=== 문서 5 추출 결과 ===")
print(f"\n엔티티 {len(extraction_05['entities'])}개:")
for e in extraction_05["entities"]:
    print(f"  [{e['type']:12s}] {e['name']}")
print(f"\n관계 {len(extraction_05['relations'])}개:")
for r in extraction_05["relations"]:
    print(f"  {r['source']} -[:{r['type']}]-> {r['target']}")

# %% [markdown]
# ---
# ## 7. 추출 통합 + 통계
#
# 5개 문서에서 추출한 결과를 합치고, 고유 엔티티/관계 통계를 확인합니다.

# %%
# 전체 추출 결과 통합
all_extractions = [extraction_01, extraction_02, extraction_03, extraction_04, extraction_05]

# 통계 계산
total_entities = sum(len(ex["entities"]) for ex in all_extractions)
total_relations = sum(len(ex["relations"]) for ex in all_extractions)

# 고유 엔티티 (이름 기준 중복 제거)
unique_entities = {}
for ex in all_extractions:
    for e in ex["entities"]:
        key = e["name"]
        if key not in unique_entities:
            unique_entities[key] = e
        else:
            # 속성 병합 (문서 4에서 supplier 추가 등)
            unique_entities[key]["properties"].update(e["properties"])

# 타입별 통계
type_counts = {}
for name, e in unique_entities.items():
    t = e["type"]
    type_counts[t] = type_counts.get(t, 0) + 1

# 관계 타입별 통계
rel_type_counts = {}
for ex in all_extractions:
    for r in ex["relations"]:
        t = r["type"]
        rel_type_counts[t] = rel_type_counts.get(t, 0) + 1

print("=== 추출 통합 통계 (문서 5개) ===")
print(f"\n  총 엔티티 멘션: {total_entities}개")
print(f"  고유 엔티티:    {len(unique_entities)}개")
print(f"  총 관계:        {total_relations}개")

print(f"\n--- 엔티티 타입별 ---")
for t, cnt in sorted(type_counts.items(), key=lambda x: -x[1]):
    print(f"  {t:15s}: {cnt}개")

print(f"\n--- 관계 타입별 ---")
for t, cnt in sorted(rel_type_counts.items(), key=lambda x: -x[1]):
    print(f"  {t:20s}: {cnt}개")

# 저장
with open("data/extractions_manufacturing.json", "w", encoding="utf-8") as f:
    json.dump(all_extractions, f, ensure_ascii=False, indent=2)
print(f"\n[OK] 추출 결과를 data/extractions_manufacturing.json에 저장했습니다.")

# %% [markdown]
# ---
# ## 8. Neo4j 적재
#
# 추출된 엔티티와 관계를 Neo4j에 적재합니다.
#
# ### MERGE vs CREATE
#
# | 명령 | 동작 | 사용 시점 |
# |------|------|----------|
# | `CREATE` | 항상 새로 생성 (중복 허용) | 처음 한 번만 생성할 때 |
# | `MERGE` | 있으면 조회, 없으면 생성 (중복 방지) | **대부분의 경우 추천** |
#
# > **핵심**: 여러 문서에서 같은 엔티티(예: MX-100 원료혼합기)가 반복 등장합니다.
# > `CREATE`를 사용하면 동일 노드가 여러 개 생기므로, 반드시 `MERGE`를 사용합니다!

# %% [markdown]
# ### 8.1 데이터베이스 초기화

# %%
# Part 2 실습을 위해 데이터베이스 초기화
run_query("MATCH (n) DETACH DELETE n", print_result=False)
print("[OK] 데이터베이스 초기화 완료")

# %%
# === 적재 함수 정의 ===

def load_entity(entity):
    """엔티티를 Neo4j에 MERGE로 적재합니다."""
    etype = entity["type"]
    name = entity["name"]
    props = entity.get("properties", {})

    query = f"""
        MERGE (n:{etype} {{name: $name}})
        ON CREATE SET n += $props
        ON MATCH SET n += $props
        RETURN n.name AS name, labels(n)[0] AS label
    """
    return run_query(query, {"name": name, "props": props}, print_result=False)


def load_relation(relation):
    """관계를 Neo4j에 MERGE로 적재합니다."""
    source = relation["source"]
    target = relation["target"]
    rtype = relation["type"]
    props = relation.get("properties", {})

    query = f"""
        MATCH (a {{name: $source}}), (b {{name: $target}})
        MERGE (a)-[r:{rtype}]->(b)
        ON CREATE SET r += $props
        ON MATCH SET r += $props
        RETURN a.name AS from_node, type(r) AS rel, b.name AS to_node
    """
    return run_query(query, {"source": source, "target": target, "props": props}, print_result=False)


print("[OK] load_entity / load_relation 함수 준비 완료")

# %%
# === 배치 적재 실행 ===

print("=== 추출 결과 Neo4j 적재 시작 ===")

entity_count = 0
relation_count = 0

for extraction in all_extractions:
    doc_id = extraction["doc_id"]
    print(f"\n--- 문서 {doc_id} 적재 중 ---")

    # 1단계: 엔티티 적재
    for entity in extraction["entities"]:
        result = load_entity(entity)
        if result:
            entity_count += 1
            print(f"  [Entity] {entity['type']:12s} | {entity['name']}")

    # 2단계: 관계 적재
    for relation in extraction["relations"]:
        result = load_relation(relation)
        if result:
            relation_count += 1
            print(f"  [Rel]    {relation['source']} -[:{relation['type']}]-> {relation['target']}")
        else:
            print(f"  [WARN]   관계 적재 실패: {relation['source']} -[:{relation['type']}]-> {relation['target']}")

print(f"\n=== 적재 완료 ===")
print(f"  엔티티: {entity_count}개 처리")
print(f"  관계:   {relation_count}개 처리")

# %% [markdown]
# ---
# ## 9. 검증 쿼리
#
# 적재된 그래프가 올바른지 검증합니다.
#
# ### 검증 체크리스트
#
# - [ ] 노드 수가 예상과 일치하는가?
# - [ ] 관계 수가 예상과 일치하는가?
# - [ ] 중복 노드가 없는가?
# - [ ] Multi-hop 쿼리가 정상 동작하는가?

# %%
# === 전체 그래프 통계 ===
print("=== 전체 그래프 통계 ===")

print("\n[1] 전체 노드 수:")
run_query("MATCH (n) RETURN count(n) AS total_nodes")

print("\n[2] 전체 관계 수:")
run_query("MATCH ()-[r]->() RETURN count(r) AS total_relations")

print("\n[3] 레이블별 노드 수:")
run_query("""
    MATCH (n)
    RETURN labels(n)[0] AS label, count(n) AS count
    ORDER BY count DESC
""")

print("\n[4] 관계 타입별 수:")
run_query("""
    MATCH ()-[r]->()
    RETURN type(r) AS rel_type, count(r) AS count
    ORDER BY count DESC
""")

# %%
# === 전체 노드 목록 ===
print("=== 전체 노드 목록 ===")
run_query("""
    MATCH (n)
    RETURN labels(n)[0] AS type, n.name AS name
    ORDER BY type, name
""")

# %%
# === 전체 관계 목록 ===
print("=== 전체 관계 목록 ===")
run_query("""
    MATCH (a)-[r]->(b)
    RETURN a.name AS from_node, type(r) AS relation, b.name AS to_node
    ORDER BY relation, from_node
""")

# %%
# === Multi-hop 검증 쿼리 ===
print("=" * 60)
print("Multi-hop 검증 쿼리")
print("=" * 60)

# 1-hop: HT-300 열처리로에서 발생하는 불량은?
print("\n[1-hop] HT-300 열처리로에서 발생하는 불량은?")
run_query("""
    MATCH (d:Defect)-[:CAUSED_BY]->(e:Equipment {name: 'HT-300 열처리로'})
    RETURN d.name AS defect, d.rate AS rate, e.name AS equipment
""")

# 2-hop: 균열 불량의 원인 설비의 정비 주기는?
print("\n[2-hop] 균열 불량의 원인 설비의 정비 주기는?")
run_query("""
    MATCH (d:Defect {name: '균열'})-[:CAUSED_BY]->(e:Equipment)
          -[:MAINTAINED_ON]->(m:Maintenance)
    RETURN d.name AS defect,
           e.name AS cause_equipment,
           m.name AS maintenance,
           m.cycle AS cycle
""")

# 3-hop: 균열 -> 원인설비(HT-300) -> 사용공정(열처리) -> 투입자재
print("\n[3-hop] 균열의 원인 설비를 사용하는 공정에 투입되는 자재는?")
run_query("""
    MATCH (d:Defect {name: '균열'})-[:CAUSED_BY]->(e:Equipment)
          <-[:USES_EQUIPMENT]-(p:Process)
          -[:USES_MATERIAL]->(mat:Material)
    RETURN d.name AS defect,
           e.name AS cause_equipment,
           p.name AS process,
           mat.name AS material
""")

print("\n" + "*" * 60)
print("3-hop 경로 해석:")
print("  균열 (결함)")
print("    --[CAUSED_BY]--> HT-300 열처리로 (설비)")
print("    <--[USES_EQUIPMENT]-- 열처리 (공정)")
print("    --[USES_MATERIAL]--> 접착제 (자재)")
print("*" * 60)

# %%
# === 공정 흐름 체인 ===
print("=== 공정 흐름 (NEXT_PROCESS chain) ===")
run_query("""
    MATCH path = (start:Process)-[:NEXT_PROCESS*]->(end:Process)
    WHERE NOT ()-[:NEXT_PROCESS]->(start)
    RETURN [n IN nodes(path) | n.name] AS process_flow,
           length(path) AS hops
    ORDER BY hops DESC
    LIMIT 1
""")
print("\n--> NEXT_PROCESS 관계를 따라 전체 공정 순서를 확인할 수 있습니다.")
print("    혼합 -> 프레스 성형 -> 열처리 -> 연마 -> 검사")

# %%
# === 중복 검사 ===
print("=== 중복 노드 검사 ===")
print("\n같은 이름의 노드가 여러 개 있는지 확인:")
run_query("""
    MATCH (n)
    WITH n.name AS name, count(n) AS cnt
    WHERE cnt > 1
    RETURN name AS duplicate_name, cnt AS count
""")

print("\n--> MERGE를 사용했으므로 중복이 없어야 합니다!")

# %% [markdown]
# ### Neo4j Browser에서 시각화하기
#
# Neo4j Browser (`http://localhost:7474`)에 접속하여 아래 쿼리를 실행하면
# 그래프를 시각적으로 확인할 수 있습니다.
#
# ```cypher
# // 전체 그래프 시각화
# MATCH (n)-[r]->(m) RETURN n, r, m
#
# // HT-300 중심 2-hop
# MATCH path = (n)-[*1..2]-(e:Equipment {name: 'HT-300 열처리로'})
# RETURN path
#
# // 공정 흐름 시각화
# MATCH path = (p1:Process)-[:NEXT_PROCESS*]->(p2:Process)
# RETURN path
# ```

# %% [markdown]
# ---
# ## 10. 정리
#
# ### 오늘 배운 것
#
# | 항목 | 내용 |
# |------|------|
# | **온톨로지 설계** | 7개 엔티티 타입(Process, Equipment, Defect, Material, Product, Spec, Maintenance) + 9개 관계 타입 정의 |
# | **수동 엔티티 추출** | 제조 문서 5개에서 엔티티/관계를 직접 추출 (15~20개 고유 노드) |
# | **Meta-Dictionary** | 9개 관계 타입별 한국어 키워드 매핑 사전 생성 |
# | **MERGE vs CREATE** | 중복 방지를 위한 MERGE 패턴 사용 |
# | **배치 적재** | Python 함수(load_entity / load_relation)로 추출 결과 자동 적재 |
# | **Multi-hop 검증** | 1-hop, 2-hop, 3-hop 쿼리로 그래프 검증 |
#
# ### Part 1 vs Part 2 비교
#
# | 항목 | Part 1 (EP1) | Part 2 |
# |------|-------------|--------|
# | 노드 수 | 7개 | 15~20개 |
# | 엔티티 타입 | 5종 | 7종 (+Spec, Maintenance) |
# | 관계 타입 | 7종 | 9종 |
# | 데이터 소스 | 직접 Cypher 입력 | 비정형 텍스트(문서 5개)에서 추출 |
# | 온톨로지 | 암묵적 | 명시적 설계 + JSON 저장 |
# | Meta-Dictionary | 없음 | 9개 관계 타입 키워드 사전 |
#
# ### 수작업의 한계
#
# 문서 5개를 추출하는 데 약 1시간이 걸렸습니다.
# 문서 100개라면? 문서 10,000개라면?
#
# > **이것이 Part 3에서 LLM 자동 추출이 필요한 이유입니다!**
#
# ### 하지만 수작업이 중요한 이유
#
# 1. **Gold Standard**: 수동 추출 결과가 LLM 결과의 품질 기준이 됩니다
# 2. **온톨로지 검증**: 설계한 스키마가 실제 데이터에 맞는지 확인할 수 있습니다
# 3. **Meta-Dictionary**: 수작업 과정에서 발견한 키워드가 LLM 프롬프트를 개선합니다
#
# ### Part 3 미리보기: LLM 기반 자동 추출
#
# Part 3에서는:
# - LLM(GPT-4)을 사용한 자동 엔티티/관계 추출
# - 오늘 만든 온톨로지 + Meta-Dictionary를 프롬프트에 활용
# - 수동 추출 결과(Gold Standard)와 자동 추출 결과 비교/평가

# %%
# 세션 정리
# driver.close()
# print("[OK] Neo4j 드라이버 종료 완료")

print("=" * 60)
print("Part 2 실습을 마칩니다.")
print("=" * 60)
print("\n오늘 배운 것:")
print("  [1] 온톨로지 설계 -- 7개 엔티티 + 9개 관계 타입")
print("  [2] 수동 엔티티 추출 -- 제조 문서 5개에서 직접 추출")
print("  [3] Meta-Dictionary -- 관계별 키워드 사전")
print("  [4] Neo4j 적재 -- MERGE 패턴으로 중복 방지")
print("  [5] Multi-hop 검증 -- 1/2/3-hop 쿼리")
print("\nPart 3에서 LLM 자동 추출로 만나요!")
